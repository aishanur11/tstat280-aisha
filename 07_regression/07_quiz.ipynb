# %% [markdown]
# ### Quiz

# %%
import pandas as pd

df = pd.read_csv("../data/fifa.csv", low_memory=False)

def clean_height(height):
    if "inches" in height:
        return float(height.replace(" inches", ""))*2.54
    else:
        return float(height.replace(" centimetres", ""))

def clean_wage(wage):
    if "K" in wage:
        return float(wage.replace("K", "000").replace("€", ""))
    else:
        return float(wage.replace("€", ""))

df["Height"] = df["Height"].map(clean_height)
df["Weight"] = df["Weight"].str.replace("lbs", "").astype("float")
df["Wage"] = df["Wage"].map(clean_wage)

# %% [markdown]
# #### Part 1
#
# Run the code block above to get a cleaned version of the FIFA dataset in `fifa.csv`. Using this cleaned dataset, create dummy variables for the `A/W` variable (attacking work rate).

# %%
df = pd.get_dummies(data=df, columns=["A/W"], drop_first=True, dtype="int")
df.head()
# Out:
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                        LongName  \
# 0                  Lionel Messi
# 1  C. Ronaldo dos Santos Aveiro
# 2                     Jan Oblak
# 3               Kevin De Bruyne
# 4    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality Positions  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina  RW ST CF
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal     ST LW
# 2  http://sofifa.com/player/200389/jan-oblak/210005/    Slovenia        GK
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium    CAM CM
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil    LW CAM
#
#                 Name  Age  ↓OVA  POT  \
# 0           L. Messi   33    93   93
# 1  Cristiano Ronaldo   35    92   92
# 2           J. Oblak   27    91   93
# 3       K. De Bruyne   29    91   91
# 4          Neymar Jr   28    91   91
#
#                                 Team & Contract  ...   IR  PAC  SHO PAS  DRI  \
# 0         \n\n\n\nFC Barcelona\n2004 ~ 2021\n\n  ...  5 ★   85   92  91   95
# 1             \n\n\n\nJuventus\n2018 ~ 2022\n\n  ...  5 ★   89   93  81   89
# 2      \n\n\n\nAtlético Madrid\n2014 ~ 2023\n\n  ...  3 ★   87   92  78   90
# 3      \n\n\n\nManchester City\n2015 ~ 2023\n\n  ...  4 ★   76   86  93   88
# 4  \n\n\n\nParis Saint-Germain\n2017 ~ 2022\n\n  ...  5 ★   91   85  86   94
#
#   DEF  PHY Hits A/W_Low A/W_Medium
# 0  38   65  372       0          1
# 1  35   77  344       0          0
# 2  52   90   86       0          1
# 3  64   78  163       0          0
# 4  36   59  273       0          0
#
# [5 rows x 78 columns]

# %% [markdown]
# #### Part 2
#
# Fit a multiple linear regression model using `Height`, `Weight` and the dummy variables for `A/W` as predictor variables and the log of `Wage` as a response variable.

# %% [markdown]
# transform the wage response variable

# %%
import numpy as np
df["log_Wage"] = np.log(df["Wage"]+1)

# %%
from sklearn.linear_model import LinearRegression

mlr_model = LinearRegression()
x_mlr = df[["Height", "Weight", "A/W_Low", "A/W_Medium"]]
y = df["log_Wage"]

mlr_model.fit(x_mlr, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Part 3
#
# Print out the intercept and coefficients for the model fit in Part 2.

# %%
print("Intercept:", mlr_model.intercept_)
print("Slope:", mlr_model.coef_)
# Out:
# Intercept: 7.143105303023985
# Slope: [-0.00487964  0.01297125 -0.66667364 -0.58665904]

# %% [markdown]
# #### Part 4
#
# Get predictions for the response variable using the model fit in Part 2 and then compute the RMSE.

# %%
from sklearn.metrics import root_mean_squared_error
mlr_pred = mlr_model.predict(x_mlr)

print("RMSE:", root_mean_squared_error(mlr_pred, y))
# Out:
# RMSE: 1.5895490117456077

# %% [markdown]
# #### Part 5
#
# Create a residual scatter plot of the predicted values on the x-axis and the residuals on the y-axis.

# %%
import seaborn as sns

resids = y - mlr_pred

sns.scatterplot(data=df, x=mlr_pred, y=resids).set_ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# #### Part 6
#
# Does there appear to be a violation of linearity for this model?

# %% [markdown]
# Yes, there appears to be a violation of linearity for this model
