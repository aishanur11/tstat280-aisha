# %% [markdown]
# I would keep the below 20 variables because it includes useful variables like address, amenities, the house size , their bedrroms numbers and the conditions of the houses which are important in predicting the house price.
#
# 1. **FireplaceY/N** -  1 value missing. deleting using case deletion, since it is negligible. Binary encode to 0's and 1's
# 2. **Structure Type** - 1 value missing. deleting using case deletion
# 3. **View Y/N** - missing 3030 data values, which is more than a half, will impute "Unknown" because it influences strongly the house price.  encode to 0, 1 and 2.
# 4. **Total bedrooms** - None
# 5. **Total parking** - 11 missing values, safe to delete using case deletion since the percentage is very small.
# 6. **New construction** 33 missing values, delete using case deletion out of the 4500 values.
# 7. **Property Condition** 2160 missing values, impute with "Unkown" since property condition affects price
# 8. **Virtual Tour** - 2856 misisng values, binary encode 'click here' to 1 and missing to 0.
# 9. **Latitude** - None
# 10. **Longitude** - None
# 11. **Air Conditioning(Y/N)** - 1 missing, case deletion, binary encode to 0 and 1
# 12. **heatingY/N** - 1 missing, case deletion, binary encode to 0 and 1
# 13. **High School District** - 86 missing values, listwise deletion since it is small percentage of data missing.
# 14. **Year Built** - None
# 15. **Total Baths** - None
# 16. **lot_size** - None  - remove Acres. convert to float
# 17. **house_size** - None - remove SQFT text, comvert to float
# 18. **Waterfront Y/N** - 120 missing, case deletion since it is small percentage. binary encode to 0 and 1
# 19. **Carport Y/N** - None
# 20. **Senior Community Y/N** - 1 missing, case deletion. binary encode to 0 and 1

# %%
import pandas as pd
df = pd.read_csv("../data/tacoma_houses.csv", low_memory = False)

selected_columns = [
    "Fireplace Y/N", 
    "Structure Type", 
    "Total Parking", 
    "New Construction", 
    "Air Conditioning Y/N",
    "Heating Y/N",
    "High School District",
    "Waterfront Y/N",
    "Senior Community Y/N",
    "Virtual Tour",
    "Carport Y/N",
    "house_size", 
    "lot_size",
    "Year Built",
    "Total Baths",
    "Longitude", 
    "Latitude",
    "Property Condition",
    "Total Bedrooms",
    "View Y/N",
    "price"
    
]
df = df[selected_columns]

# %% [markdown]
# check for duplicates

# %%
df.duplicated().sum()
# Out:
# 37

# %%
df[df.duplicated()]
# Out:
#      Fireplace Y/N      Structure Type  Total Parking New Construction  \
# 758            Yes               House            2.0               No
# 944             No               House            2.0               No
# 968            Yes               House            1.0               No
# 1007           Yes               House            2.0               No
# 1181           Yes               House            0.0               No
# 1225           Yes               House            1.0               No
# 1359           Yes               House            0.0               No
# 1384           Yes               House           10.0               No
# 1406           Yes               House            0.0               No
# 1539           Yes               House            3.0               No
# 1607           Yes               House            0.0               No
# 1907           Yes               House            5.0               No
# 1995            No               House            1.0               No
# 2133            No               House            0.0               No
# 2330           Yes               House            2.0               No
# 2348           Yes               House            2.0               No
# 2614            No               House            2.0               No
# 2693           Yes               House            2.0               No
# 2732           Yes               House            1.0               No
# 2750            No               House            2.0               No
# 3030           Yes               House            2.0               No
# 3062           Yes               House            2.0               No
# 3118            No               House            2.0               No
# 3137            No  Manufactured House            0.0               No
# 3184            No               House            2.0               No
# 3223           Yes               House            2.0               No
# 3242           Yes               House            0.0               No
# 3362           Yes               House            1.0               No
# 3950           Yes               House            2.0               No
# 3995            No               House            2.0               No
# 4150            No               House            2.0               No
# 4177           Yes               House            1.0               No
# 4235           Yes               House            2.0               No
# 4400           Yes               House            6.0               No
# 4404           Yes               House            1.0               No
# 4473            No               House            1.0               No
# 4495           Yes               House            3.0               No
#
#      Air Conditioning Y/N Heating Y/N High School District Waterfront Y/N  \
# 758                   Yes         Yes               Tacoma             No
# 944                   Yes         Yes               Tacoma             No
# 968                    No         Yes               Tacoma             No
# 1007                   No         Yes          Clover Park            Yes
# 1181                  Yes         Yes               Tacoma             No
# 1225                   No         Yes               Tacoma             No
# 1359                  Yes         Yes               Tacoma             No
# 1384                  Yes         Yes      Franklin Pierce             No
# 1406                   No         Yes               Tacoma             No
# 1539                   No         Yes               Tacoma             No
# 1607                   No         Yes               Tacoma             No
# 1907                  Yes         Yes               Tacoma             No
# 1995                   No         Yes               Tacoma             No
# 2133                  Yes         Yes               Tacoma             No
# 2330                   No         Yes               Tacoma             No
# 2348                  Yes         Yes      Franklin Pierce             No
# 2614                  Yes         Yes               Tacoma             No
# 2693                   No         Yes      Franklin Pierce             No
# 2732                   No         Yes               Tacoma             No
# 2750                  Yes         Yes               Tacoma             No
# 3030                   No         Yes               Bethel             No
# 3062                  Yes         Yes               Tacoma             No
# 3118                   No         Yes      Franklin Pierce             No
# 3137                  Yes         Yes      Franklin Pierce             No
# 3184                   No         Yes               Bethel             No
# 3223                  Yes         Yes      Franklin Pierce             No
# 3242                   No         Yes               Tacoma             No
# 3362                   No         Yes               Tacoma             No
# 3950                   No         Yes               Tacoma             No
# 3995                   No         Yes                 Fife             No
# 4150                   No         Yes               Tacoma             No
# 4177                  Yes         Yes               Tacoma             No
# 4235                  Yes         Yes               Tacoma             No
# 4400                  Yes         Yes               Tacoma             No
# 4404                  Yes         Yes               Tacoma             No
# 4473                  Yes         Yes               Tacoma             No
# 4495                  Yes         Yes                 Fife             No
#
#      Senior Community Y/N Virtual Tour  ...  house_size    lot_size  \
# 758                    No   Click here  ...  3,008 SQFT  0.26 Acres
# 944                    No          NaN  ...  1,832 SQFT  0.23 Acres
# 968                    No   Click here  ...  1,605 SQFT  0.14 Acres
# 1007                   No   Click here  ...  3,239 SQFT  0.24 Acres
# 1181                   No   Click here  ...  1,032 SQFT  0.14 Acres
# 1225                   No   Click here  ...  1,437 SQFT  0.20 Acres
# 1359                   No   Click here  ...  1,425 SQFT  0.05 Acres
# 1384                   No   Click here  ...  3,294 SQFT  3.00 Acres
# 1406                   No   Click here  ...  2,288 SQFT  0.18 Acres
# 1539                   No   Click here  ...  2,366 SQFT  0.22 Acres
# 1607                   No   Click here  ...  2,064 SQFT  0.23 Acres
# 1907                   No   Click here  ...  1,677 SQFT  0.23 Acres
# 1995                   No          NaN  ...  2,020 SQFT  0.21 Acres
# 2133                   No          NaN  ...    800 SQFT  0.24 Acres
# 2330                   No          NaN  ...  2,004 SQFT  0.16 Acres
# 2348                  Yes   Click here  ...  1,904 SQFT  0.11 Acres
# 2614                   No          NaN  ...  1,160 SQFT  2.02 Acres
# 2693                   No   Click here  ...  1,056 SQFT  0.19 Acres
# 2732                   No          NaN  ...  1,002 SQFT  0.13 Acres
# 2750                   No          NaN  ...    624 SQFT  0.21 Acres
# 3030                   No          NaN  ...  2,202 SQFT  0.15 Acres
# 3062                   No          NaN  ...  1,780 SQFT  0.17 Acres
# 3118                   No          NaN  ...  1,677 SQFT  0.08 Acres
# 3137                   No          NaN  ...  1,682 SQFT  0.55 Acres
# 3184                   No   Click here  ...  2,112 SQFT  0.43 Acres
# 3223                   No   Click here  ...  1,794 SQFT  0.41 Acres
# 3242                   No          NaN  ...  1,348 SQFT  0.11 Acres
# 3362                   No          NaN  ...  1,464 SQFT  0.13 Acres
# 3950                   No   Click here  ...  1,571 SQFT  0.15 Acres
# 3995                   No   Click here  ...    866 SQFT  0.18 Acres
# 4150                   No   Click here  ...  1,080 SQFT  0.14 Acres
# 4177                   No          NaN  ...  2,226 SQFT  0.12 Acres
# 4235                   No          NaN  ...  1,394 SQFT  0.16 Acres
# 4400                   No          NaN  ...  4,233 SQFT  0.63 Acres
# 4404                   No   Click here  ...  1,572 SQFT  0.19 Acres
# 4473                   No   Click here  ...    764 SQFT  0.14 Acres
# 4495                   No   Click here  ...  3,688 SQFT  0.38 Acres
#
#      Year Built  Total Baths   Longitude   Latitude  Property Condition  \
# 758        1977            3 -122.430267  47.307781                 NaN
# 944        1991            3 -122.409941  47.300871                 NaN
# 968        1945            2 -122.491473  47.266188                 NaN
# 1007       1968            3 -122.539840  47.163103           Very Good
# 1181       1945            1 -122.454259  47.211670                 NaN
# 1225       1960            1 -122.503212  47.244594           Very Good
# 1359       1925            2 -122.458513  47.257834           Very Good
# 1384       2009            3 -122.367091  47.142176                 NaN
# 1406       1968            2 -122.487954  47.248507                 NaN
# 1539       1990            3 -122.416335  47.303190           Very Good
# 1607       1948            2 -122.552146  47.242934                 NaN
# 1907       1953            2 -122.508174  47.276351                 NaN
# 1995       1955            2 -122.496966  47.251964                 NaN
# 2133       1920            2 -122.408185  47.227219                 NaN
# 2330       2003            3 -122.496094  47.200519           Remodeled
# 2348       2015            2 -122.399228  47.126112                 NaN
# 2614       1933            2 -122.365438  47.169173           Remodeled
# 2693       1951            2 -122.455173  47.165089                 NaN
# 2732       1945            1 -122.491097  47.261570                Fair
# 2750       1919            1 -122.492578  47.196889                 NaN
# 3030       2003            3 -122.408828  47.113106           Very Good
# 3062       1979            2 -122.520744  47.284373                 NaN
# 3118       2010            3 -122.417638  47.149961                Good
# 3137       1984            2 -122.432401  47.146704           Very Good
# 3184       2002            2 -122.371835  47.114556           Very Good
# 3223       1959            2 -122.379266  47.140550                Good
# 3242       1921            1 -122.454394  47.229408                 NaN
# 3362       1976            3 -122.498614  47.201638                 NaN
# 3950       1952            2 -122.511396  47.270704           Remodeled
# 3995       1944            1 -122.335718  47.261143                Good
# 4150       1910            1 -122.437108  47.202571                 NaN
# 4177       1941            2 -122.493267  47.275097                 NaN
# 4235       1950            1 -122.497653  47.253215                Good
# 4400       1981            3 -122.423992  47.312815           Remodeled
# 4404       1929            2 -122.398158  47.229230   Updated/Remodeled
# 4473       1920            1 -122.497260  47.254236           Very Good
# 4495       2015            4 -122.346022  47.264263           Very Good
#
#      Total Bedrooms  View Y/N        price
# 758               5       Yes    $975,000
# 944               4       Yes    $760,000
# 968               4       NaN    $730,000
# 1007              4       Yes  $1,485,000
# 1181              3       NaN    $433,900
# 1225              4       NaN    $480,000
# 1359              3        No    $450,000
# 1384              5       Yes  $1,550,000
# 1406              4       NaN    $538,000
# 1539              3       NaN    $820,000
# 1607              3       NaN    $485,000
# 1907              3       Yes    $710,000
# 1995              4       NaN    $535,000
# 2133              2        No    $375,000
# 2330              3       NaN    $625,000
# 2348              3       Yes    $535,000
# 2614              2        No    $600,000
# 2693              3       Yes    $415,000
# 2732              2       Yes    $466,000
# 2750              2        No    $370,000
# 3030              4       NaN    $564,950
# 3062              3       Yes    $560,000
# 3118              4       NaN    $462,500
# 3137              3       NaN    $444,000
# 3184              4       NaN    $599,900
# 3223              3       NaN    $565,000
# 3242              3        No    $390,000
# 3362              3       NaN    $510,000
# 3950              3       NaN    $635,000
# 3995              2       Yes    $439,000
# 4150              3       NaN    $440,000
# 4177              4       NaN    $730,000
# 4235              2        No    $487,500
# 4400              5       NaN  $1,250,000
# 4404              3       NaN    $600,000
# 4473              2       NaN    $501,000
# 4495              4       NaN    $975,000
#
# [37 rows x 21 columns]

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Deleting the missing values from variables using case deletion

# %%
df.dropna(subset=["Fireplace Y/N", 
                  "Structure Type", 
                  "Total Parking", 
                  "New Construction", 
                  "Air Conditioning Y/N",
                  "Heating Y/N",
                  "High School District",
                  "Waterfront Y/N",
                  "Senior Community Y/N"
                 ], inplace = True)

# %% [markdown]
# Impute values to missing values in View Y/N, Property Condition and Virtual Tour

# %%
df["View Y/N"] = df["View Y/N"].fillna("Unknown")
df["Property Condition"] = df["Property Condition"].fillna("Unknown")
df["Virtual Tour"] = df["Virtual Tour"].fillna("No")

df["Virtual Tour"] = df["Virtual Tour"].str.replace("Click here", "Yes")

# %% [markdown]
# Encoding categorical variables

# %%
Binary_columns = [
    "Fireplace Y/N", 
    "Air Conditioning Y/N",
    "Heating Y/N",
    "Waterfront Y/N",
    "Senior Community Y/N",
    "View Y/N",
    "Virtual Tour",
    "Carport Y/N"
]

for col in Binary_columns:
    df[col] = df[col].map({
        "Yes": 1,
        "No": 0,
        "Unknown": 2
    })

# %%
df[["Fireplace Y/N", 
    "Air Conditioning Y/N",
    "Heating Y/N",
    "Waterfront Y/N",
    "Senior Community Y/N",
    "View Y/N", 
    "Virtual Tour",
    "Carport Y/N"
   ]]
# Out:
#       Fireplace Y/N  Air Conditioning Y/N  Heating Y/N  Waterfront Y/N  \
# 0                 0                     0            1               0
# 1                 1                     0            1               0
# 2                 1                     1            1               0
# 3                 1                     0            1               0
# 4                 0                     0            1               0
# ...             ...                   ...          ...             ...
# 4504              1                     1            1               0
# 4505              1                     0            1               0
# 4506              0                     0            1               0
# 4507              1                     0            1               0
# 4508              1                     1            1               0
#
#       Senior Community Y/N  View Y/N  Virtual Tour  Carport Y/N
# 0                        0         0             0            0
# 1                        0         1             1            0
# 2                        0         2             0            0
# 3                        0         2             1            0
# 4                        0         2             0            0
# ...                    ...       ...           ...          ...
# 4504                     0         1             1            1
# 4505                     0         2             1            0
# 4506                     0         0             0            0
# 4507                     0         2             0            0
# 4508                     0         1             1            0
#
# [4242 rows x 8 columns]

# %% [markdown]
# standardized property condition variable

# %%
df["Property Condition"].unique()
# Out:
# array(['Unknown', 'Very Good', 'Good', 'Under Construction',
#        'Updated/Remodeled', 'Remodeled', 'Fixer', 'Average', 'Fair',
#        'Restored'], dtype=object)

# %%
df["Property Condition"] = df["Property Condition"].map({
    "Updated/Remodeled": "Remod",
    "Fixer": "Fixer",
    "Remodeled": "Remod",
    "Average": "Average",
    "Fair": "Fair",
    "Restored": "Restored",
    "Very Good": "V.Good",
    "Good": "Good",
    "Under Construction": "Under Const.",
    "Unknown": "Unk"
})
df["Property Condition"].unique()
# Out:
# array(['Unk', nan, 'Good', 'Remod', 'Fixer', 'Average', 'Fair',
#        'Restored'], dtype=object)

# %% [markdown]
# standardizing units of house_size and lot_size

# %%
df["house_size"]
# Out:
# 0         800 SQFT
# 1       1,944 SQFT
# 2       1,916 SQFT
# 3       1,436 SQFT
# 4         951 SQFT
#            ...
# 4504    1,536 SQFT
# 4505    2,134 SQFT
# 4506    1,902 SQFT
# 4507    1,800 SQFT
# 4508    3,601 SQFT
# Name: house_size, Length: 4242, dtype: object

# %%
df["house_size"] = df["house_size"].str.replace("SQFT", "").str.replace(",", "").astype("float")
df["house_size"]
# Out:
# 0        800.0
# 1       1944.0
# 2       1916.0
# 3       1436.0
# 4        951.0
#          ...
# 4504    1536.0
# 4505    2134.0
# 4506    1902.0
# 4507    1800.0
# 4508    3601.0
# Name: house_size, Length: 4242, dtype: float64

# %%
df["lot_size"]
# Out:
# 0       0.48 Acres
# 1       0.23 Acres
# 2       0.14 Acres
# 3       0.13 Acres
# 4       0.15 Acres
#            ...
# 4504    0.30 Acres
# 4505    0.18 Acres
# 4506    0.13 Acres
# 4507    0.15 Acres
# 4508    0.48 Acres
# Name: lot_size, Length: 4242, dtype: object

# %%
ACRE_TO_SQFT = 43560

lot_multiplier = df["lot_size"].str.contains("Acres").map(
    lambda x: ACRE_TO_SQFT if x else 1
)

df["lot_size"] = df["lot_size"].str.replace("Acres", "").astype("float")*lot_multiplier

df["lot_size"].describe()
# Out:
# count      4242.000000
# mean      10723.954455
# std       23452.523271
# min           0.000000
# 25%        5227.200000
# 50%        6534.000000
# 75%        9147.600000
# max      653400.000000
# Name: lot_size, dtype: float64

# %%
df["lot_size"].describe()
# Out:
# count      4242.000000
# mean      10723.954455
# std       23452.523271
# min           0.000000
# 25%        5227.200000
# 50%        6534.000000
# 75%        9147.600000
# max      653400.000000
# Name: lot_size, dtype: float64

# %%
df.isnull().sum()
# Out:
# Fireplace Y/N           0
# Structure Type          0
# Total Parking           0
# New Construction        0
# Air Conditioning Y/N    0
# Heating Y/N             0
# High School District    0
# Waterfront Y/N          0
# Senior Community Y/N    0
# Virtual Tour            0
# Carport Y/N             0
# house_size              0
# lot_size                0
# Year Built              0
# Total Baths             0
# Longitude               0
# Latitude                0
# Property Condition      0
# Total Bedrooms          0
# View Y/N                0
# price                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4242 entries, 0 to 4508
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fireplace Y/N         4242 non-null   int64
#  1   Structure Type        4242 non-null   object
#  2   Total Parking         4242 non-null   float64
#  3   New Construction      4242 non-null   object
#  4   Air Conditioning Y/N  4242 non-null   int64
#  5   Heating Y/N           4242 non-null   int64
#  6   High School District  4242 non-null   object
#  7   Waterfront Y/N        4242 non-null   int64
#  8   Senior Community Y/N  4242 non-null   int64
#  9   Virtual Tour          4242 non-null   int64
#  10  Carport Y/N           4242 non-null   int64
#  11  house_size            4242 non-null   float64
#  12  lot_size              4242 non-null   float64
#  13  Year Built            4242 non-null   int64
#  14  Total Baths           4242 non-null   int64
#  15  Longitude             4242 non-null   float64
#  16  Latitude              4242 non-null   float64
#  17  Property Condition    4242 non-null   object
#  18  Total Bedrooms        4242 non-null   int64
#  19  View Y/N              4242 non-null   int64
#  20  price                 4242 non-null   object
# dtypes: float64(5), int64(11), object(5)
# memory usage: 729.1+ KB

# %% [markdown]
# ## (Univariate Distribution)

# %% [markdown]
# clean the response variable price

# %%
df["price"]
# Out:
# 0         $280,000
# 1         $530,000
# 2         $585,950
# 3         $530,000
# 4         $475,000
#            ...
# 4504      $530,000
# 4505      $592,000
# 4506      $520,000
# 4507      $332,500
# 4508    $1,950,000
# Name: price, Length: 4242, dtype: object

# %%
df["price"] = df["price"].str.replace("$", "").str.replace(",", "").astype(int)
df["price"]
# Out:
# 0        280000
# 1        530000
# 2        585950
# 3        530000
# 4        475000
#          ...
# 4504     530000
# 4505     592000
# 4506     520000
# 4507     332500
# 4508    1950000
# Name: price, Length: 4242, dtype: int64

# %%
import seaborn as sns
sns.histplot(data=df, x="price")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# transform the data

# %%
import numpy as np
df["log_price"] = np.log(df["price"])

sns.histplot(data=df, x="log_price")
# Out:
# <Axes: xlabel='log_price', ylabel='Count'>

# %% [markdown]
# distribution for numerical predictor variables

# %%
sns.pairplot(df, vars=[
    "Total Parking", 
    "house_size", 
    "lot_size",
    "Year Built",
    "Longitude", 
    "Latitude",
    "Total Bedrooms"
    ])

# %%
df.describe()
# Out:
#        Fireplace Y/N  Total Parking  Air Conditioning Y/N  Heating Y/N  \
# count    4242.000000    4242.000000           4242.000000  4242.000000
# mean        0.556577       2.116926              0.477605     0.992692
# std         0.496847      21.181557              0.499557     0.085183
# min         0.000000       0.000000              0.000000     0.000000
# 25%         0.000000       1.000000              0.000000     1.000000
# 50%         1.000000       2.000000              0.000000     1.000000
# 75%         1.000000       2.000000              1.000000     1.000000
# max         1.000000     960.000000              1.000000     1.000000
#
#        Waterfront Y/N  Senior Community Y/N  Virtual Tour  Carport Y/N  \
# count     4242.000000            4242.00000   4242.000000  4242.000000
# mean         0.006365               0.00330      0.330504     0.094767
# std          0.079536               0.05736      0.470450     0.292927
# min          0.000000               0.00000      0.000000     0.000000
# 25%          0.000000               0.00000      0.000000     0.000000
# 50%          0.000000               0.00000      0.000000     0.000000
# 75%          0.000000               0.00000      1.000000     0.000000
# max          1.000000               1.00000      1.000000     1.000000
#
#         house_size       lot_size   Year Built  Total Baths    Longitude  \
# count  4242.000000    4242.000000  4242.000000  4242.000000  4242.000000
# mean   1695.938472   10723.954455  1959.949081     2.116455  -122.446706
# std     724.376525   23452.523271    36.438476     0.880568     0.045602
# min     408.000000       0.000000  1888.000000     1.000000  -122.591346
# 25%    1196.000000    5227.200000  1926.000000     1.000000  -122.477516
# 50%    1539.500000    6534.000000  1959.000000     2.000000  -122.444997
# 75%    2040.750000    9147.600000  1989.000000     3.000000  -122.412805
# max    7300.000000  653400.000000  2026.000000     7.000000  -122.321369
#
#           Latitude  Total Bedrooms     View Y/N         price    log_price
# count  4242.000000     4242.000000  4242.000000  4.242000e+03  4242.000000
# mean     47.213643        3.236917     1.470061  5.475072e+05    13.152424
# std       0.054451        0.891536     0.797411  2.226446e+05     0.342828
# min      47.058851        1.000000     0.000000  7.000000e+02     6.551080
# 25%      47.179669        3.000000     1.000000  4.161500e+05    12.938801
# 50%      47.214531        3.000000     2.000000  4.990000e+05    13.120361
# 75%      47.257417        4.000000     2.000000  6.100000e+05    13.321214
# max      47.318861        9.000000     2.000000  3.300000e+06    15.009433

# %%
sns.countplot(data=df, x="Property Condition")
# Out:
# <Axes: xlabel='Property Condition', ylabel='count'>

# %%
df["High School District"].unique()
# Out:
# array(['Tacoma', 'Franklin Pierce', 'Bethel', 'Arlington', 'Puyallup',
#        'Clover Park', 'Steilacoom Historica', 'Fife', 'Marysville',
#        'University Place', 'Lakewood', 'Federal Way', 'Tahoma'],
#       dtype=object)

# %% [markdown]
# standardized values of high school district predictor variable

# %%
df["High School District"] = df["High School District"].map({
    "Tacoma": "TAC",
    "Franklin Pierce": "FP",
    "Bethel": "BTH",
    "Arlington": "ARL",
    "Puyallup": "PUY",
    "Clover Park": "CP",
    "Steilacoom Historica": "STH",
    "Fife": "FIF",
    "Marysville": "MARY",
    "University Place": "UP",
    "Lakewood": "LKWD",
    "Federal Way": "FW",
    "Tahoma": "TAH"
}
    
)

# %%
sns.countplot(data=df, x="High School District")
# Out:
# <Axes: xlabel='High School District', ylabel='count'>

# %%
sns.countplot(data=df, x="Structure Type")
# Out:
# <Axes: xlabel='Structure Type', ylabel='count'>

# %% [markdown]
# ## Relationship between variables

# %% [markdown]
# checking for multicollinearity between numeric variables

# %% [markdown]
# The Total Bedrooms and housing size shows is strongly positive correlated, meaning bigger house size is associated with more bedrooms. This may indicate multicollinearity between the two variables since both show similar information about the size of the house.

# %%
correla = df[[  "Total Parking", 
    "house_size", 
    "lot_size",
    "Year Built",
    "Longitude", 
    "Latitude",
    "Total Bedrooms"]].corr()
sns.heatmap(correla, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# House size had the highest correlation with the response variable, followed by total baths. This suggests that larger homes and homes with more bathrooms tend to have higher house prices. Total Bedrooms also showed a moderate positive relationship with the response variable.

# %%
sns.heatmap(df.corr(numeric_only=True)[["log_price"]], annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Lot size is th4e one with the most right skewed distribution, hence transformating to normal

# %%
sns.histplot(data=df, x="lot_size")
# Out:
# <Axes: xlabel='lot_size', ylabel='Count'>

# %%
df["log_lot_size"] = np.log(df["lot_size"])
sns.histplot(data=df, x="log_lot_size")
# Out:
# <Axes: xlabel='log_lot_size', ylabel='Count'>

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# The scatterplot does not show a very strong linear relationship between house_age and log_price. Both newer and older homes appear across a wide range of prices, suggesting that house age alone may not be a strong predictor of house price.

# %%
df["house_age"] = 2026 - df["Year Built"]

sns.scatterplot(data=df, x="log_price", y="house_age")
# Out:
# <Axes: xlabel='log_price', ylabel='house_age'>
