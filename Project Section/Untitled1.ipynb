# %% [markdown]
# 1. arrival congestion
# 2. flight distance
# 3. average cruise speed
# 4. taekoff weight
# 5. total(airbone_time+taxi_out_time + holding_time)
# 6. weather condition
# 7. aircraft_type
# 8. engine_model
# 9. cruise altitude
# 10.

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("../data/fuel.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        1000 non-null   object
#  1   departure_airport             1000 non-null   object
#  2   weather_condition             1000 non-null   object
#  3   cloud_type                    1000 non-null   object
#  4   jet_stream_region             1000 non-null   object
#  5   arrival_congestion            1000 non-null   object
#  6   aircraft_type                 1000 non-null   object
#  7   upholstery_style              1000 non-null   object
#  8   engine_model                  1000 non-null   object
#  9   manufacturer_country          1000 non-null   object
#  10  terminal_architecture         1000 non-null   object
#  11  flight_distance               1000 non-null   float64
# ...

# %%
df["total_time"] = df["taxi_out_time"] + df["holding_time"] + df["airborne_time"]

# %%
df["total_time"].describe()
# Out:
# count    1000.000000
# mean      336.000341
# std       247.231386
# min        57.733265
# 25%       175.861017
# 50%       263.747587
# 75%       412.032321
# max      2039.748157
# Name: total_time, dtype: float64

# %%
corr_matrix = df[["total_time", "fuel_consumption" ]].corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >
