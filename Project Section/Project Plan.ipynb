# %%
PROJECT PLAN

# %% [markdown]
# 1. Who is the stakeholder and what do they want to accomplish?

# %% [raw]
# Stakeholder is Maya who is trying to make better decisions around housing, both for buyers and for people working in the housing market.

# %% [markdown]
# 2. Is this a supervised learning or unsupervised learning problem? If it is a supervised learning problem, does it sound like a regression or classification task?

# %% [raw]
# it is a supervised learning that sounds like a regression because of the estimate of the cost of the house that is needed.

# %% [markdown]
# 3. Which of the individuals sounds like a data engineer?
#  Where do the data come from?
#  What problems are there with the data?
#  How will you address any of these problems?

# %% [raw]
# Luis is the data engineer because he gathered the information.
#
# The data came from homes data like size, number of rooms, and past sale prices. Also surrounding areas data like crime reports, some broader neighborhood-level indicators, and information about nearby places—like parks, restaurants, transit stops, and schools.
#
# The problems are the following with the data;
# - Missing values in some columns
# - Inconsistent formatting (especially for locations or names)
# - Possible duplicates or repeated entries
# - Data collected at different times or levels of detail.
# - Stored in multiple files that don’t align perfectly.
#
# I would address each of the problems;
# - I would impute mean or median for the numericals, the mode or "unknown" for the categoricals.
# - I would standardize the formats of the data. eg names, location.
# - Identify duplicates and carefully remove them if they are true duplicates.
# - I would join the different data tables using join.
# - I would aggregate times to match.

# %% [markdown]
# 4. Which of the individuals sounds like a data analyst?
#  What are some trends they've noticed in the past?
#  What are some suggestions they have for future data analyses?

# %% [raw]
# Aisha is the data analyst.
#
# - First, not all homes behave the same. Some neighborhoods seem to have very different price
# ranges, even for houses that look similar on paper. That suggests that location plays a big role.
# - I also noticed that certain features—like square footage and number of bedrooms—seem to
# matter, but not always in a simple way. Bigger isn’t always better if other factors aren’t there.
#
# - Look at how price relates to size, number of rooms, and lot size
# - Compare prices across different areas
# - See whether homes near certain types of places (like parks or schools) tend to be priced differently.
# - Check if there are any unusual or extreme values that might affect the results
# - It’s also worth taking time to really understand the distributions of your variables and how they relate to each other.

# %% [markdown]
# 5. Which of the individuals sounds like a machine learning engineer?
#  What are some things to consider when building the model?
#  What are some things to consider when presenting the model for others to use?
#  What are some things you want to account for when deploying the model?

# %% [raw]
# Ethan is the machine learning engineer because
#
# - One way to check how well your approach is working. If your predictions are consistently far off, that’s a problem.
# - It’s also important to test your approach on data it hasn’t seen before. Otherwise, you might end up with something that looks good at first but doesn’t actually work in practice.
#
# - When it comes to sharing the results, simplicity is key. The tool we build should let someone
# enter a few details about a home and quickly get a prediction. It should be clear what inputs are
# required and easy to interpret the output.
#
# - What happens if someone enters unusual or incomplete information
# - How fast the tool responds
# - Whether the results are easy to trust and understand.

# %% [markdown]
# 6. Which of the individuals sounds like a subject matter expert?
#  What variables will be useful for prediction?
#  What variables aren't readily available that might require extra effort to construct?

# %% [raw]
# Dr.Chen is the subject matter Expert.
#
# - Useful varibales include locations, number of amenities, distance to amenities, crime levels, house size, condition and number of bedrooms.
#
# - Variables aren't readily available that might require extra effort to construct like size of the home with the location or condition of amenities, This may require combining multiple data set or creating new features.
